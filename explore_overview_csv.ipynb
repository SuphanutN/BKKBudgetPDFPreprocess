# %%
import pandas as pd

# %%
MODULE_PATH = (r'C:\Users\Suphanut\Documents\Work\metamedia\datathon')

# %%
file_path = MODULE_PATH+r"\dataset\district"

df = pd.read_csv(file_path, encoding="utf-8")

pd.set_option('float_format', '{:f}'.format)

# %%
df
# Out:
#                                  topic       price
# 0              (21)  สำนักงานเขตพระนคร   412864000
# 1   (22)  สำนักงานเขตป้อมปราบศัตรูพ่าย   252196000
# 2         (23)  สำนักงานเขตสัมพันธวงศ์   208176600
# 3              (24)  สำนักงานเขตบางรัก   246445000
# 4             (25)  สำนักงานเขตปทุมวัน   354141000
# 5             (26)  สำนักงานเขตยานนาวา   310196614
# 6               (27)  สำนักงานเขตดุสิต   401245000
# 7               (28)  สำนักงานเขตพญาไท   335172500
# 8            (29)  สำนักงานเขตห้วยขวาง   352262000
# 9             (30)  สำนักงานเขตพระโขนง   281172800
# 10            (31)  สำนักงานเขตบางกะปิ   524131000
# 11             (32)  สำนักงานเขตบางเขน   421948600
# 12            (33)  สำนักงานเขตมีนบุรี   509962100
# 13          (34)  สำนักงานเขตลาดกระบัง   567466000
# 14            (35)  สำนักงานเขตหนองจอก   589363000
# 15             (36)  สำนักงานเขตธนบุรี   397104900
# 16            (37)  สำนักงานเขตคลองสาน   309402000
# ...

# %%
df.describe()
# Out:
#                   price
# count         50.000000
# mean   436985588.840000
# std    399566472.500239
# min    208176600.000000
# 25%    316893250.000000
# 50%    374072300.000000
# 75%    420184550.000000
# max   3134633000.000000

# %%
df.nlargest(5, 'price')
# Out:
#                              topic       price
# 49  (71)  มหาวิทยาลัยนวมินทราธิราช  3134633000
# 14        (35)  สำนักงานเขตหนองจอก   589363000
# 32         (54)  สำนักงานเขตประเวศ   584808000
# 22    (43)  สำนักงานเขตบางขุนเทียน   579297000
# 13      (34)  สำนักงานเขตลาดกระบัง   567466000

# %%
df.nsmallest(5, 'price')
# Out:
#                                  topic      price
# 2         (23)  สำนักงานเขตสัมพันธวงศ์  208176600
# 3              (24)  สำนักงานเขตบางรัก  246445000
# 1   (22)  สำนักงานเขตป้อมปราบศัตรูพ่าย  252196000
# 17         (38)  สำนักงานเขตบางกอกใหญ่  267938900
# 41           (63)  สำนักงานเขตคันนายาว  274038900

# %%
ax = df.plot.hist(bins=15, alpha=0.5)

# %%
hist
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027138541AC8>]],
#       dtype=object)

# %%
df_remove_outliner = df.drop([49])

# %%
df_remove_outliner
# Out:
#                                  topic      price
# 0              (21)  สำนักงานเขตพระนคร  412864000
# 1   (22)  สำนักงานเขตป้อมปราบศัตรูพ่าย  252196000
# 2         (23)  สำนักงานเขตสัมพันธวงศ์  208176600
# 3              (24)  สำนักงานเขตบางรัก  246445000
# 4             (25)  สำนักงานเขตปทุมวัน  354141000
# 5             (26)  สำนักงานเขตยานนาวา  310196614
# 6               (27)  สำนักงานเขตดุสิต  401245000
# 7               (28)  สำนักงานเขตพญาไท  335172500
# 8            (29)  สำนักงานเขตห้วยขวาง  352262000
# 9             (30)  สำนักงานเขตพระโขนง  281172800
# 10            (31)  สำนักงานเขตบางกะปิ  524131000
# 11             (32)  สำนักงานเขตบางเขน  421948600
# 12            (33)  สำนักงานเขตมีนบุรี  509962100
# 13          (34)  สำนักงานเขตลาดกระบัง  567466000
# 14            (35)  สำนักงานเขตหนองจอก  589363000
# 15             (36)  สำนักงานเขตธนบุรี  397104900
# 16            (37)  สำนักงานเขตคลองสาน  309402000
# 17         (38)  สำนักงานเขตบางกอกใหญ่  267938900
# ...

# %%
ax = df_remove_outliner.plot.hist(bins=12, alpha=0.5)
